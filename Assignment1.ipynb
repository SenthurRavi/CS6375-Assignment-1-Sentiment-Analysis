# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# False

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#      ----------------------- ---------------- 2.4/4.0 MB 13.4 MB/s eta 0:00:01
#      ---------------------------------------- 4.0/4.0 MB 12.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/2.7 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.7 GB 11.2 MB/s eta 0:04:01
#      ---------------------------------------- 0.0/2.7 GB 12.5 MB/s eta 0:03:37
#      ---------------------------------------- 0.0/2.7 GB 12.6 MB/s eta 0:03:34
#      ---------------------------------------- 0.0/2.7 GB 12.6 MB/s eta 0:03:34
#      ---------------------------------------- 0.0/2.7 GB 12.7 MB/s eta 0:03:31
#      ---------------------------------------- 0.0/2.7 GB 12.9 MB/s eta 0:03:28
#      ---------------------------------------- 0.0/2.7 GB 12.8 MB/s eta 0:03:29
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
torch.cuda.get_device_name(0)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 torch.cuda.get_device_name(0)
#
# File ~\anaconda3\envs\cs6375\lib\site-packages\torch\cuda\__init__.py:435, in get_device_name(device)
#     423 def get_device_name(device: Optional[_device_t] = None) -> str:
#     424     r"""Get the name of a device.
#     425
#     426     Args:
#    (...)
#     433         str: the name of the device
#     434     """
# --> 435     return get_device_properties(device).name
#
# File ~\anaconda3\envs\cs6375\lib\site-packages\torch\cuda\__init__.py:465, in get_device_properties(device)
#     455 def get_device_properties(device: _device_t) -> _CudaDeviceProperties:
#     456     r"""Get the properties of a device.
#     457
#     458     Args:
#    (...)
#     463         _CudaDeviceProperties: the properties of the device
#     464     """
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !python ffnn.py --hidden_dim 32 --epochs 50 --train_data training.json --val_data validation.json
# Out:
# ========== Loading data ==========
# ========== Vectorizing data ==========
# Traceback (most recent call last):
#   File "ffnn.py", line 125, in <module>
#     train_data = convert_to_vector_representation(train_data, word2index)
#   File "ffnn.py", line 69, in convert_to_vector_representation
#     vector = torch.zeros.to(device)(len(word2index))
# AttributeError: 'builtin_function_or_method' object has no attribute 'to'

# %%
# !python ffnn.py --hidden_dim 32 --epochs 50 --train_data training.json --val_data validation.json
# Out:
# ========== Loading data ==========
# ========== Vectorizing data ==========
# ========== Training for 50 epochs ==========
# Training started for epoch 1
# Training completed for epoch 1
# Training accuracy for epoch 1: 0.533625
# Training time for this epoch: 31.784663200378418
# Validation started for epoch 1
# Validation completed for epoch 1
# Validation accuracy for epoch 1: 0.5225
# Validation time for this epoch: 0.7677819728851318
# Training started for epoch 2
# Training completed for epoch 2
# Training accuracy for epoch 2: 0.58375
# Training time for this epoch: 30.151134967803955
# Validation started for epoch 2
# Validation completed for epoch 2
# Validation accuracy for epoch 2: 0.56625
# Validation time for this epoch: 0.6496906280517578
# Training started for epoch 3
# Training completed for epoch 3
# Training accuracy for epoch 3: 0.61775
# Training time for this epoch: 29.505548238754272
# Validation started for epoch 3
# Validation completed for epoch 3
# ...

# %%
# !python rnn.py --hidden_dim 32 --epochs 10 --train_data training.json --val_data validation.json
# Out:
# Loading data...
# Initializing model...
# Traceback (most recent call last):
#   File "rnn.py", line 76, in <module>
#     word_embeddings = pickle.load(open('./word_embedding.pkl', 'rb'))
# FileNotFoundError: [Errno 2] No such file or directory: './word_embedding.pkl'

# %%
# !python rnn.py --hidden_dim 32 --epochs 10 --train_data training.json --val_data validation.json
# Out:
# Loading data...
# Initializing model...
# Traceback (most recent call last):
#   File "rnn.py", line 76, in <module>
#     word_embeddings = pickle.load(open('./word_embedding.pkl', 'rb'))
# FileNotFoundError: [Errno 2] No such file or directory: './word_embedding.pkl'

# %%
# !python rnn.py --hidden_dim 32 --epochs 10 --train_data training.json --val_data validation.json
# Out:
# Loading data...
# Initializing model...
# Training epoch 1
#   0%|          | 0/250 [00:00<?, ?it/s]rnn.py:112: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
#   input_tensor = torch.tensor(input_vectors, dtype=torch.float32).unsqueeze(1)
#
#   0%|          | 0/250 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "rnn.py", line 114, in <module>
#     output = model(input_tensor)
#   File "C:\Users\senth\anaconda3\envs\cs6375\lib\site-packages\torch\nn\modules\module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "C:\Users\senth\anaconda3\envs\cs6375\lib\site-packages\torch\nn\modules\module.py", line 1562, in _call_impl
# ...

# %%
# !python rnn.py --hidden_dim 32 --epochs 10 --train_data training.json --val_data validation.json
# Out:
# Loading data...
# Initializing model...
# Training epoch 1
# ...
#   0%|          | 0/250 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "rnn.py", line 115, in <module>
#     output = model(input_tensor)
#   File "C:\Users\senth\anaconda3\envs\cs6375\lib\site-packages\torch\nn\modules\module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "C:\Users\senth\anaconda3\envs\cs6375\lib\site-packages\torch\nn\modules\module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "rnn.py", line 34, in forward
#     rnn_output, hidden_state = self.rnn(inputs, hidden_state)
#   File "C:\Users\senth\anaconda3\envs\cs6375\lib\site-packages\torch\nn\modules\module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "C:\Users\senth\anaconda3\envs\cs6375\lib\site-packages\torch\nn\modules\module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
# ...

# %%
# !python rnn.py --hidden_dim 32 --epochs 10 --train_data training.json --val_data validation.json
# Out:
# Loading data...
# Initializing model...
# Training epoch 1
# ...
#   0%|          | 0/250 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "rnn.py", line 118, in <module>
#     batch_loss += model.compute_loss(output, torch.tensor([label]))
#   File "rnn.py", line 30, in compute_loss
#     return self.loss_function(predicted_output, true_label)
#   File "C:\Users\senth\anaconda3\envs\cs6375\lib\site-packages\torch\nn\modules\module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "C:\Users\senth\anaconda3\envs\cs6375\lib\site-packages\torch\nn\modules\module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "C:\Users\senth\anaconda3\envs\cs6375\lib\site-packages\torch\nn\modules\loss.py", line 218, in forward
#     return F.nll_loss(input, target, weight=self.weight, ignore_index=self.ignore_index, reduction=self.reduction)
# ...

# %%
# !python rnn.py --hidden_dim 32 --epochs 10 --train_data training.json --val_data validation.json
# Out:
# Loading data...
# Initializing model...
# Training epoch 1
#   0%|          | 0/250 [00:00<?, ?it/s]rnn.py:112: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:281.)
#   input_tensor = torch.tensor(input_vectors, dtype=torch.float32).unsqueeze(1)
#
#   0%|          | 0/250 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "rnn.py", line 114, in <module>
#     output = model(input_tensor)
#   File "C:\Users\senth\anaconda3\envs\cs6375\lib\site-packages\torch\nn\modules\module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "C:\Users\senth\anaconda3\envs\cs6375\lib\site-packages\torch\nn\modules\module.py", line 1562, in _call_impl
# ...

# %%
# !python rnn.py --hidden_dim 32 --epochs 10 --train_data training.json --val_data validation.json
# Out:
# Loading data...
# Initializing model...
# Training epoch 1
# ...
#   0%|          | 0/250 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "rnn.py", line 115, in <module>
#     output = model(input_tensor)
#   File "C:\Users\senth\anaconda3\envs\cs6375\lib\site-packages\torch\nn\modules\module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "C:\Users\senth\anaconda3\envs\cs6375\lib\site-packages\torch\nn\modules\module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "rnn.py", line 35, in forward
#     rnn_output, hidden_state = self.rnn(inputs, hidden_state)
#   File "C:\Users\senth\anaconda3\envs\cs6375\lib\site-packages\torch\nn\modules\module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "C:\Users\senth\anaconda3\envs\cs6375\lib\site-packages\torch\nn\modules\module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
# ...

# %%
# !python rnn.py --hidden_dim 32 --epochs 10 --train_data training.json --val_data validation.json
# Out:
# Using device: cuda
# Loading data...
# Initializing model...
#
# Training epoch 1 / 10
# Epoch 1: Training accuracy = 0.4016, Training loss = 34.9774
# Epoch 1: Validation accuracy = 0.4000
#
# Training epoch 2 / 10
# Epoch 2: Training accuracy = 0.4031, Training loss = 34.3737
# Epoch 2: Validation accuracy = 0.3862
#
# Training epoch 3 / 10
# Epoch 3: Training accuracy = 0.4017, Training loss = 34.1387
# Epoch 3: Validation accuracy = 0.3987
#
# Training epoch 4 / 10
# Epoch 4: Training accuracy = 0.4030, Training loss = 34.1618
# Epoch 4: Validation accuracy = 0.3975
#
# Training epoch 5 / 10
# Epoch 5: Training accuracy = 0.4019, Training loss = 34.0610
# Epoch 5: Validation accuracy = 0.4188
#
# Training epoch 6 / 10
# Epoch 6: Training accuracy = 0.3984, Training loss = 34.1084
# Epoch 6: Validation accuracy = 0.4088
#
# Training epoch 7 / 10
# Epoch 7: Training accuracy = 0.3900, Training loss = 34.1248
# Epoch 7: Validation accuracy = 0.4050
#
# Training epoch 8 / 10
# ...

# %%
# !python plot_results.py
# Out:
# Figure(1200x600)

# %%
import json

# Load results from JSON file
with open("results_rnn.json", "r") as file:
    results = json.load(file)

# Print results
print("Training Losses:", results["train_losses"])
print("Validation Accuracies:", results["val_accuracies"])
# Out:
# Training Losses: [34.97736068725586, 34.37373606109619, 34.138725143432616, 34.16182430267334, 34.061034446716306, 34.108356155395505, 34.124848808288576, 34.067239128112796, 34.085233680725096, 34.020681640625]
# Validation Accuracies: [0.4, 0.38625, 0.39875, 0.3975, 0.41875, 0.40875, 0.405, 0.40125, 0.4, 0.40125]

# %%
import torch
import numpy as np

# Load the trained model
model = torch.load("rnn_model.pth", map_location=device)  # Load the saved model
model.eval()  # Set model to evaluation mode

# Example sentence
example_sentence = ["this", "movie", "was", "amazing"]
input_vectors = np.random.rand(len(example_sentence), 50)  # Create random embeddings

# Convert to tensor and move to GPU
input_tensor = torch.tensor(input_vectors, dtype=torch.float32).unsqueeze(1).to(device)

# Run the model
output = model(input_tensor)
predicted_label = torch.argmax(output, dim=1).item()

# Convert prediction to sentiment label
sentiment_labels = {0: "Very Negative", 1: "Negative", 2: "Neutral", 3: "Positive", 4: "Very Positive"}
print("Predicted Sentiment:", sentiment_labels[predicted_label])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 import numpy as np
#       4 # Load the trained model
# ----> 5 model = torch.load("rnn_model.pth", map_location=device)  # Load the saved model
#       6 model.eval()  # Set model to evaluation mode
#       8 # Example sentence
#
# NameError: name 'device' is not defined

# %%
import torch
import numpy as np

# Set the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load the trained model
model = torch.load("rnn_model.pth", map_location=device)  # Load the saved model
model.to(device)  # Move model to GPU if available
model.eval()  # Set model to evaluation mode

# Example sentence
example_sentence = ["this", "movie", "was", "amazing"]
input_vectors = np.random.rand(len(example_sentence), 50)  # Create random embeddings

# Convert to tensor and move to GPU
input_tensor = torch.tensor(input_vectors, dtype=torch.float32).unsqueeze(1).to(device)

# Run the model
output = model(input_tensor)
predicted_label = torch.argmax(output, dim=1).item()

# Convert prediction to sentiment label
sentiment_labels = {0: "Very Negative", 1: "Negative", 2: "Neutral", 3: "Positive", 4: "Very Positive"}
print("Predicted Sentiment:", sentiment_labels[predicted_label])
# Out:
# C:\Users\senth\AppData\Local\Temp\ipykernel_15456\246172585.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
import torch
import numpy as np

# 1) Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# 2) (Optional) Load your saved model
#    Make sure you have "rnn_model.pth" in your folder,
#    otherwise comment out these lines or rename the file accordingly.
try:
    model = torch.load("rnn_model.pth", map_location=device)
    model.to(device)
    print("Model loaded and moved to:", device)
except FileNotFoundError:
    print("No rnn_model.pth file found. Creating a dummy model for demonstration.")
    # Creating a dummy model for demonstration
    class DummyModel(torch.nn.Module):
        def __init__(self):
            super().__init__()
            self.fc = torch.nn.Linear(50, 5)  # input_dim=50, 5 sentiment classes
            self.softmax = torch.nn.LogSoftmax(dim=1)
        def forward(self, x):
            x = self.fc(x[-1])  # take last time step for demonstration
            return self.softmax(x)
    model = DummyModel().to(device)

model.eval()  # set model to evaluation mode

# 3) Example sentence with random embeddings
example_sentence = ["this", "movie", "was", "amazing"]
input_vectors = np.random.rand(len(example_sentence), 50)  # shape: (seq_len, input_dim)

# Convert to torch tensor => shape: (seq_len, 1, input_dim)
input_tensor = torch.tensor(input_vectors, dtype=torch.float32).unsqueeze(1).to(device)

# 4) Run the model
output = model(input_tensor)
predicted_label = torch.argmax(output, dim=1).item()

# 5) Print result
sentiment_labels = {0: "Very Negative", 1: "Negative", 2: "Neutral", 3: "Positive", 4: "Very Positive"}
print("Predicted Sentiment:", sentiment_labels.get(predicted_label, "Unknown"))
# Out:
# Using device: cuda
# No rnn_model.pth file found. Creating a dummy model for demonstration.
# Predicted Sentiment: Positive
# ...

# %%
import torch
import numpy as np

# 1) Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# 2) (Optional) Load your saved model
#    Make sure you have "rnn_model.pth" in your folder,
#    otherwise comment out these lines or rename the file accordingly.
try:
    model = torch.load("rnn_model.pth", map_location=device)
    model.to(device)
    print("Model loaded and moved to:", device)
except FileNotFoundError:
    print("No rnn_model.pth file found. Creating a dummy model for demonstration.")
    # Creating a dummy model for demonstration
    class DummyModel(torch.nn.Module):
        def __init__(self):
            super().__init__()
            self.fc = torch.nn.Linear(50, 5)  # input_dim=50, 5 sentiment classes
            self.softmax = torch.nn.LogSoftmax(dim=1)
        def forward(self, x):
            x = self.fc(x[-1])  # take last time step for demonstration
            return self.softmax(x)
    model = DummyModel().to(device)

model.eval()  # set model to evaluation mode

# 3) Example sentence with random embeddings
example_sentence = ["this", "movie", "was", "stupid"]
input_vectors = np.random.rand(len(example_sentence), 50)  # shape: (seq_len, input_dim)

# Convert to torch tensor => shape: (seq_len, 1, input_dim)
input_tensor = torch.tensor(input_vectors, dtype=torch.float32).unsqueeze(1).to(device)

# 4) Run the model
output = model(input_tensor)
predicted_label = torch.argmax(output, dim=1).item()

# 5) Print result
sentiment_labels = {0: "Very Negative", 1: "Negative", 2: "Neutral", 3: "Positive", 4: "Very Positive"}
print("Predicted Sentiment:", sentiment_labels.get(predicted_label, "Unknown"))
# Out:
# Using device: cuda
# No rnn_model.pth file found. Creating a dummy model for demonstration.
# ...

# %%
import torch
import numpy as np

# 1) Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# 2) (Optional) Load your saved model
#    Make sure you have "rnn_model.pth" in your folder,
#    otherwise comment out these lines or rename the file accordingly.
try:
    model = torch.load("rnn_model.pth", map_location=device)
    model.to(device)
    print("Model loaded and moved to:", device)
except FileNotFoundError:
    print("No rnn_model.pth file found. Creating a dummy model for demonstration.")
    # Creating a dummy model for demonstration
    class DummyModel(torch.nn.Module):
        def __init__(self):
            super().__init__()
            self.fc = torch.nn.Linear(50, 5)  # input_dim=50, 5 sentiment classes
            self.softmax = torch.nn.LogSoftmax(dim=1)
        def forward(self, x):
            x = self.fc(x[-1])  # take last time step for demonstration
            return self.softmax(x)
    model = DummyModel().to(device)

model.eval()  # set model to evaluation mode

# 3) Example sentence with random embeddings
example_sentence = ["this", "movie", "was", "not", "good"]
input_vectors = np.random.rand(len(example_sentence), 50)  # shape: (seq_len, input_dim)

# Convert to torch tensor => shape: (seq_len, 1, input_dim)
input_tensor = torch.tensor(input_vectors, dtype=torch.float32).unsqueeze(1).to(device)

# 4) Run the model
output = model(input_tensor)
predicted_label = torch.argmax(output, dim=1).item()

# 5) Print result
sentiment_labels = {0: "Very Negative", 1: "Negative", 2: "Neutral", 3: "Positive", 4: "Very Positive"}
print("Predicted Sentiment:", sentiment_labels.get(predicted_label, "Unknown"))
# Out:
# Using device: cuda
# No rnn_model.pth file found. Creating a dummy model for demonstration.
# ...
